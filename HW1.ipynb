# %%
import numpy as np
np.version.version
# Out:
# '1.16.2'

# %%
import pandas as pd
df = pd.read_csv('data.csv')
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# 5          BMW    1 Series  2012     premium unleaded (required)      230.0
# 6          BMW    1 Series  2012     premium unleaded (required)      300.0
# 7          BMW    1 Series  2012     premium unleaded (required)      300.0
# 8          BMW    1 Series  2012     premium unleaded (required)      230.0
# 9          BMW    1 Series  2013     premium unleaded (required)      230.0
# 10         BMW    1 Series  2013     premium unleaded (required)      300.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
# Make                 11914 non-null object
# Model                11914 non-null object
# Year                 11914 non-null int64
# Engine Fuel Type     11911 non-null object
# Engine HP            11845 non-null float64
# Engine Cylinders     11884 non-null float64
# Transmission Type    11914 non-null object
# Driven_Wheels        11914 non-null object
# Number of Doors      11908 non-null float64
# Market Category      8172 non-null object
# Vehicle Size         11914 non-null object
# Vehicle Style        11914 non-null object
# highway MPG          11914 non-null int64
# city mpg             11914 non-null int64
# Popularity           11914 non-null int64
# MSRP                 11914 non-null int64
# dtypes: float64(3), int64(5), object(8)
# memory usage: 1.5+ MB

# %%
df['Make'].value_counts()
# Out:
# Chevrolet        1123
# Ford              881
# Volkswagen        809
# Toyota            746
# Dodge             626
# Nissan            558
# GMC               515
# Honda             449
# Mazda             423
# Cadillac          397
# Mercedes-Benz     353
# Suzuki            351
# BMW               334
# Infiniti          330
# Audi              328
# Hyundai           303
# Volvo             281
# Subaru            256
# Acura             252
# Kia               231
# Mitsubishi        213
# Lexus             202
# Buick             196
# Chrysler          187
# Pontiac           186
# Lincoln           164
# Oldsmobile        150
# Land Rover        143
# Porsche           136
# Saab              111
# Aston Martin       93
# Plymouth           82
# Bentley            74
# Ferrari            69
# FIAT               62
# Scion              60
# Maserati           58
# Lamborghini        52
# Rolls-Royce        31
# Lotus              29
# Tesla              18
# ...

# %%
df[df[] == 'Audi'].nunique()
# Out:
#   File "<ipython-input-59-91d43e1461e8>", line 1
#     df[df[] == 'Audi'].nunique()
#           ^
# SyntaxError: invalid syntax

# %%
df.groupby(df['Make'] == 'Audi').Model.nunique()
# Out:
# Make
# False    884
# True      34
# Name: Model, dtype: int64

# %%
df.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
df['Engine Cylinders'].median()
# Out:
# 6.0

# %%
df['Engine Cylinders'].value_counts()
# Out:
# 4.0     4752
# 6.0     4489
# 8.0     2031
# 12.0     230
# 5.0      225
# 10.0      68
# 0.0       56
# 3.0       30
# 16.0       3
# Name: Engine Cylinders, dtype: int64

# %%
most_common_value = df['Engine Cylinders'].value_counts().index[0]
df['Engine Cylinders'] = df['Engine Cylinders'].fillna(most_common_value)

# %%
df['Engine Cylinders'].median()
# Out:
# 6.0

# %%
X = df[df['Make'] == 'Lotus'][['Engine HP', 'Engine Cylinders']].drop_duplicates()

# %%
XTX = X @ X.T
XTX
# Out:
#          3912     3913     3918      4216      4257      4259      4262  \
# 3912  35737.0  41218.0  41029.0   66182.0   75624.0   52188.0   65229.0
# 3913  41218.0  47540.0  47322.0   76332.0   87224.0   60192.0   75234.0
# 3918  41029.0  47322.0  47105.0   75982.0   86824.0   59916.0   74889.0
# 4216  66182.0  76332.0  75982.0  122564.0  140048.0   96648.0  120798.0
# 4257  75624.0  87224.0  86824.0  140048.0  160036.0  110436.0  138036.0
# 4259  52188.0  60192.0  59916.0   96648.0  110436.0   76212.0   95256.0
# 4262  65229.0  75234.0  74889.0  120798.0  138036.0   95256.0  119061.0
# 4292  48589.0  56042.0  55785.0   89982.0  102824.0   70956.0   88689.0
# 4293  45376.0  52336.0  52096.0   84032.0   96024.0   66264.0   82824.0
#
#           4292     4293
# 3912   48589.0  45376.0
# 3913   56042.0  52336.0
# 3918   55785.0  52096.0
# 4216   89982.0  84032.0
# 4257  102824.0  96024.0
# 4259   70956.0  66264.0
# 4262   88689.0  82824.0
# 4292   66065.0  61696.0
# ...

# %%
XTX_inv = np.linalg.inv(XTX)
XTX_inv
# Out:
# array([[ 4.87854228e+14,  4.87854228e+14, -2.43927114e+14,
#         -4.43700836e+02,  0.00000000e+00,  0.00000000e+00,
#          9.75708456e+14,  0.00000000e+00, -5.69668096e+13],
#        [-1.24321703e+18,  1.21537533e+18,  1.04678949e+18,
#          1.19309393e+06,  1.54368015e+18,  1.24322538e+18,
#         -2.34615637e+18, -2.88769717e+17, -1.39803086e+18],
#        [ 3.10909462e+30, -3.00802229e+30, -2.60616862e+30,
#         -2.92378543e+18, -3.80766291e+30, -3.09060098e+30,
#          5.80287311e+30,  7.16740439e+29,  3.43144202e+30],
#        [-3.76282469e+29,  3.63025500e+29,  3.15826586e+29,
#          3.51724729e+17,  4.59903441e+29,  3.73803774e+29,
#         -7.01429734e+29, -8.57588282e+28, -4.15227010e+29],
#        [ 7.99442796e+17, -7.82411008e+17, -6.77374261e+17,
#          2.25179981e+15, -9.88182636e+17, -8.00396110e+17,
#          1.50711850e+18,  1.86616235e+17,  8.91413013e+17],
#        [ 2.85365708e+26,  3.64589806e+26, -1.90821110e+27,
# ...

# %%
y = np.array([1100, 800, 750, 850, 1300, 1000, 1000, 1300, 800])
y
# Out:
# array([1100,  800,  750,  850, 1300, 1000, 1000, 1300,  800])

# %%
w = (XTX_inv @ X.T) * y
w
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-449829436c31> in <module>
# ----> 1 w = (XTX_inv @ X.T) * y
#       2 w
#
# ~\AppData\Local\Continuum\anaconda3\envs\retinanet\lib\site-packages\pandas\core\frame.py in __rmatmul__(self, other)
#    1051         Matrix multiplication using binary `@` operator in Python>=3.5.
#    1052         """
# -> 1053         return self.T.dot(np.transpose(other)).T
#    1054
#    1055     # ----------------------------------------------------------------------
#
# ~\AppData\Local\Continuum\anaconda3\envs\retinanet\lib\site-packages\pandas\core\frame.py in dot(self, other)
#    1025                 raise ValueError('Dot product shape mismatch, '
#    1026                                  '{s} vs {r}'.format(s=lvals.shape,
# -> 1027                                                      r=rvals.shape))
#    1028
# ...
